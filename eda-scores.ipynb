# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/vietnam-national-hs-graduation-exam-2021/2021.csv

# %%
df = pd.read_csv("../input/vietnam-national-hs-graduation-exam-2021/2021.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       id  year  mathematics_score  literature_score  \
# 0           0  1000046  2022                8.0              6.25
# 1           1  1000031  2022                7.0              7.75
# 2           2  1000012  2022                6.4              7.50
# 3           3  1000087  2022                8.4              8.00
# 4           4  1000071  2022                7.6              8.25
#
#    physics_score  chemistry_score  biology_score  foreign_language_score  \
# 0           7.25              5.5           4.75                     4.6
# 1            NaN              NaN            NaN                     8.8
# 2            NaN              NaN            NaN                     NaN
# 3            NaN              NaN            NaN                     9.4
# 4           6.25              5.0           3.25                     6.6
#
#   foreign_language_type  english_score  history_score  geography_score  \
# ...

# %%
df = df.iloc[:,1:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995381 entries, 0 to 995380
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   year                    995381 non-null  int64
#  1   mathematics_score       982670 non-null  float64
#  2   literature_score        981351 non-null  float64
#  3   physics_score           325510 non-null  float64
#  4   chemistry_score         327353 non-null  float64
#  5   biology_score           322185 non-null  float64
#  6   foreign_language_score  870571 non-null  float64
#  7   foreign_language_type   870571 non-null  object
#  8   english_score           866151 non-null  float64
#  9   history_score           659617 non-null  float64
#  10  geography_score         657377 non-null  float64
#  11  civic_education_score   554316 non-null  float64
#  12  chinese_score           2467 non-null    float64
# ...

# %%
df.describe()
# Out:
#            year  mathematics_score  literature_score  physics_score  \
# count  995381.0      982670.000000     981351.000000  325510.000000
# mean     2022.0           6.466307          6.507771       6.723776
# std         0.0           1.675402          1.379598       1.441914
# min      2022.0           0.000000          0.000000       0.000000
# 25%      2022.0           5.400000          5.580000       5.750000
# 50%      2022.0           6.800000          6.500000       7.000000
# 75%      2022.0           7.800000          7.500000       7.750000
# max      2022.0          10.000000         10.000000      10.000000
#
#        chemistry_score  biology_score  foreign_language_score  english_score  \
# count    327353.000000  322185.000000           870571.000000  866151.000000
# mean          6.703872       5.019119                5.157718       5.146637
# std           1.600390       1.448270                1.949552       1.942451
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="mathematics_score")
# Out:
# <AxesSubplot:xlabel='mathematics_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.histplot(data=df,x="literature_score",bins=10)
# Out:
# <AxesSubplot:xlabel='literature_score', ylabel='Count'>

# %%
plt.figure(figsize=(20,4))
sns.histplot(data=df,x="physics_score",bins=10)
# Out:
# <AxesSubplot:xlabel='physics_score', ylabel='Count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="chemistry_score")
# Out:
# <AxesSubplot:xlabel='chemistry_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="biology_score")
# Out:
# <AxesSubplot:xlabel='biology_score', ylabel='count'>

# %%
df.describe().iloc[1:,1:].T.plot(kind="bar",figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="foreign_language_score")
# Out:
# <AxesSubplot:xlabel='foreign_language_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="foreign_language_type")
# Out:
# <AxesSubplot:xlabel='foreign_language_type', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="foreign_language_score")
# Out:
# <AxesSubplot:xlabel='foreign_language_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.histplot(data=df,x="english_score",bins=10)
# Out:
# <AxesSubplot:xlabel='english_score', ylabel='Count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="history_score")
# Out:
# <AxesSubplot:xlabel='history_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="chinese_score")
# Out:
# <AxesSubplot:xlabel='chinese_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="japanese_score")
# Out:
# <AxesSubplot:xlabel='japanese_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="french_score")
# Out:
# <AxesSubplot:xlabel='french_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df,x="russian_score")
# Out:
# <AxesSubplot:xlabel='russian_score', ylabel='count'>

# %%
plt.figure(figsize=(20,4))
sns.scatterplot(data=df,x="physics_score",y="chemistry_score")
# Out:
# <AxesSubplot:xlabel='physics_score', ylabel='chemistry_score'>
