# %% [markdown]
# <a href="https://www.kaggle.com/code/syedasimalishah/saving-memory-for-large-datasets?scriptVersionId=107620632" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tabular-playground-series-oct-2022/sample_submission.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_9.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_3.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_4.csv
# /kaggle/input/tabular-playground-series-oct-2022/test_dtypes.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_8.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_dtypes.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_5.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_2.csv
# /kaggle/input/tabular-playground-series-oct-2022/test.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_0.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_7.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_1.csv
# /kaggle/input/tabular-playground-series-oct-2022/train_6.csv

# %%
dtypes_df = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_dtypes.csv')
dtypes = {k: v for (k, v) in zip(dtypes_df.column, dtypes_df.dtype)}
df1 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_0.csv',dtype=dtypes)
df2 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_1.csv',dtype=dtypes)
df3 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_2.csv',dtype=dtypes)
df4 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_3.csv',dtype=dtypes)
df5 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_4.csv',dtype=dtypes)
df6 = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/train_5.csv',dtype=dtypes)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6])

# %%
del df1,df2,df3,df4,df5,df6

# %%
dft = pd.read_csv('/kaggle/input/tabular-playground-series-oct-2022/test.csv')

# %%
df= df.dropna()
df.shape
# Out:
# (9351578, 61)

# %%
trainXA = df[['ball_pos_x', 'ball_pos_y', 'ball_pos_z', 'ball_vel_x',
       'ball_vel_y', 'ball_vel_z', 'p0_pos_x', 'p0_pos_y', 'p0_pos_z',
       'p0_vel_x', 'p0_vel_y', 'p0_vel_z', 'p0_boost', 'p1_pos_x', 'p1_pos_y',
       'p1_pos_z', 'p1_vel_x', 'p1_vel_y', 'p1_vel_z', 'p1_boost', 'p2_pos_x',
       'p2_pos_y', 'p2_pos_z', 'p2_vel_x', 'p2_vel_y', 'p2_vel_z', 'p2_boost',
       'p3_pos_x', 'p3_pos_y', 'p3_pos_z', 'p3_vel_x', 'p3_vel_y', 'p3_vel_z',
       'p3_boost', 'p4_pos_x', 'p4_pos_y', 'p4_pos_z', 'p4_vel_x', 'p4_vel_y',
       'p4_vel_z', 'p4_boost', 'p5_pos_x', 'p5_pos_y', 'p5_pos_z', 'p5_vel_x',
       'p5_vel_y', 'p5_vel_z', 'p5_boost', 'boost0_timer', 'boost1_timer',
       'boost2_timer', 'boost3_timer', 'boost4_timer', 'boost5_timer']]
trainYA = df[['team_A_scoring_within_10sec']]

# %%
trainXB = df[['ball_pos_x', 'ball_pos_y', 'ball_pos_z', 'ball_vel_x',
       'ball_vel_y', 'ball_vel_z', 'p0_pos_x', 'p0_pos_y', 'p0_pos_z',
       'p0_vel_x', 'p0_vel_y', 'p0_vel_z', 'p0_boost', 'p1_pos_x', 'p1_pos_y',
       'p1_pos_z', 'p1_vel_x', 'p1_vel_y', 'p1_vel_z', 'p1_boost', 'p2_pos_x',
       'p2_pos_y', 'p2_pos_z', 'p2_vel_x', 'p2_vel_y', 'p2_vel_z', 'p2_boost',
       'p3_pos_x', 'p3_pos_y', 'p3_pos_z', 'p3_vel_x', 'p3_vel_y', 'p3_vel_z',
       'p3_boost', 'p4_pos_x', 'p4_pos_y', 'p4_pos_z', 'p4_vel_x', 'p4_vel_y',
       'p4_vel_z', 'p4_boost', 'p5_pos_x', 'p5_pos_y', 'p5_pos_z', 'p5_vel_x',
       'p5_vel_y', 'p5_vel_z', 'p5_boost', 'boost0_timer', 'boost1_timer',
       'boost2_timer', 'boost3_timer', 'boost4_timer', 'boost5_timer']]

trainYB = df[['team_B_scoring_within_10sec']]

# %%
test = dft[['ball_pos_x', 'ball_pos_y', 'ball_pos_z', 'ball_vel_x',
       'ball_vel_y', 'ball_vel_z', 'p0_pos_x', 'p0_pos_y', 'p0_pos_z',
       'p0_vel_x', 'p0_vel_y', 'p0_vel_z', 'p0_boost', 'p1_pos_x', 'p1_pos_y',
       'p1_pos_z', 'p1_vel_x', 'p1_vel_y', 'p1_vel_z', 'p1_boost', 'p2_pos_x',
       'p2_pos_y', 'p2_pos_z', 'p2_vel_x', 'p2_vel_y', 'p2_vel_z', 'p2_boost',
       'p3_pos_x', 'p3_pos_y', 'p3_pos_z', 'p3_vel_x', 'p3_vel_y', 'p3_vel_z',
       'p3_boost', 'p4_pos_x', 'p4_pos_y', 'p4_pos_z', 'p4_vel_x', 'p4_vel_y',
       'p4_vel_z', 'p4_boost', 'p5_pos_x', 'p5_pos_y', 'p5_pos_z', 'p5_vel_x',
       'p5_vel_y', 'p5_vel_z', 'p5_boost', 'boost0_timer', 'boost1_timer',
       'boost2_timer', 'boost3_timer', 'boost4_timer', 'boost5_timer']]

# %%
test.fillna(test.mean(), inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
del df,dft

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
trainXA = scaler.fit_transform(trainXA)
trainXB = scaler.fit_transform(trainXB)
test = scaler.fit_transform(test)

# %%
trainXA = pd.DataFrame(trainXA)
trainXB = pd.DataFrame(trainXB)
test = pd.DataFrame(test)

# %%
trainXA.shape
# Out:
# (9351578, 54)

# %%
import tensorflow as tf
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# instantiating the model in the strategy scope creates the model on the TPU
with tpu_strategy.scope():
    modelA = Sequential()
    modelA.add(Dense(256, input_shape=(54,), activation='relu'))
    modelA.add(Dense(128,activation='relu'))
    modelA.add(Dense(64,activation='relu'))
    modelA.add(Dense(1, activation='sigmoid'))
    modelA.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    modelA.fit(trainXA,trainYA,epochs=50, steps_per_epoch=4)
# Out:
# 2022-10-10 06:35:12.379740: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-10-10 06:35:12.379853: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30177}
# 2022-10-10 06:35:12.386381: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-10-10 06:35:12.386428: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30177}
# 2022-10-10 06:35:20.480298: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2019940848 exceeds 10% of free system memory.
# Epoch 1/50
# 4/4 [==============================] - 6s 182ms/step - loss: 0.7561 - accuracy: 0.3994
# Epoch 2/50
# 4/4 [==============================] - 1s 300ms/step - loss: 0.3414 - accuracy: 0.9273
# Epoch 3/50
# 4/4 [==============================] - 1s 312ms/step - loss: 0.2711 - accuracy: 0.9273
# Epoch 4/50
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2867 - accuracy: 0.9273
# Epoch 5/50
# 4/4 [==============================] - 1s 311ms/step - loss: 0.2790 - accuracy: 0.9272
# Epoch 6/50
# 4/4 [==============================] - 1s 339ms/step - loss: 0.2582 - accuracy: 0.9273
# Epoch 7/50
# 4/4 [==============================] - 1s 314ms/step - loss: 0.2484 - accuracy: 0.9273
# Epoch 8/50
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2493 - accuracy: 0.9272
# Epoch 9/50
# 4/4 [==============================] - 1s 287ms/step - loss: 0.2499 - accuracy: 0.9273
# Epoch 10/50
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2472 - accuracy: 0.9272
# Epoch 11/50
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2443 - accuracy: 0.9273
# Epoch 12/50
# 4/4 [==============================] - 1s 296ms/step - loss: 0.2437 - accuracy: 0.9273
# Epoch 13/50
# 4/4 [==============================] - 1s 299ms/step - loss: 0.2438 - accuracy: 0.9272
# Epoch 14/50
# 4/4 [==============================] - 1s 308ms/step - loss: 0.2431 - accuracy: 0.9273
# Epoch 15/50
# 4/4 [==============================] - 1s 318ms/step - loss: 0.2421 - accuracy: 0.9273
# Epoch 16/50
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2418 - accuracy: 0.9273
# Epoch 17/50
# 4/4 [==============================] - 1s 301ms/step - loss: 0.2416 - accuracy: 0.9272
# Epoch 18/50
# 4/4 [==============================] - 1s 307ms/step - loss: 0.2412 - accuracy: 0.9273
# Epoch 19/50
# 4/4 [==============================] - 1s 304ms/step - loss: 0.2408 - accuracy: 0.9273
# Epoch 20/50
# 4/4 [==============================] - 1s 281ms/step - loss: 0.2405 - accuracy: 0.9273
# Epoch 21/50
# 4/4 [==============================] - 1s 289ms/step - loss: 0.2404 - accuracy: 0.9273
# Epoch 22/50
# 4/4 [==============================] - 1s 302ms/step - loss: 0.2402 - accuracy: 0.9272
# Epoch 23/50
# 4/4 [==============================] - 1s 293ms/step - loss: 0.2400 - accuracy: 0.9272
# Epoch 24/50
# 4/4 [==============================] - 1s 301ms/step - loss: 0.2398 - accuracy: 0.9272
# Epoch 25/50
# 4/4 [==============================] - 1s 304ms/step - loss: 0.2397 - accuracy: 0.9272
# Epoch 26/50
# 4/4 [==============================] - 1s 296ms/step - loss: 0.2395 - accuracy: 0.9273
# Epoch 27/50
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2392 - accuracy: 0.9273
# Epoch 28/50
# 4/4 [==============================] - 1s 307ms/step - loss: 0.2394 - accuracy: 0.9272
# Epoch 29/50
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2390 - accuracy: 0.9273
# Epoch 30/50
# 4/4 [==============================] - 1s 297ms/step - loss: 0.2391 - accuracy: 0.9272
# Epoch 31/50
# 4/4 [==============================] - 1s 293ms/step - loss: 0.2387 - accuracy: 0.9272
# Epoch 32/50
# 4/4 [==============================] - 1s 294ms/step - loss: 0.2387 - accuracy: 0.9272
# Epoch 33/50
# 4/4 [==============================] - 1s 295ms/step - loss: 0.2387 - accuracy: 0.9272
# Epoch 34/50
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2382 - accuracy: 0.9273
# Epoch 35/50
# 4/4 [==============================] - 1s 279ms/step - loss: 0.2381 - accuracy: 0.9273
# Epoch 36/50
# 4/4 [==============================] - 1s 277ms/step - loss: 0.2381 - accuracy: 0.9273
# Epoch 37/50
# 4/4 [==============================] - 1s 289ms/step - loss: 0.2379 - accuracy: 0.9273
# Epoch 38/50
# 4/4 [==============================] - 1s 275ms/step - loss: 0.2379 - accuracy: 0.9273
# Epoch 39/50
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2377 - accuracy: 0.9273
# Epoch 40/50
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2375 - accuracy: 0.9273
# Epoch 41/50
# 4/4 [==============================] - 1s 287ms/step - loss: 0.2377 - accuracy: 0.9272
# Epoch 42/50
# 4/4 [==============================] - 1s 284ms/step - loss: 0.2374 - accuracy: 0.9273
# Epoch 43/50
# 4/4 [==============================] - 1s 292ms/step - loss: 0.2373 - accuracy: 0.9273
# Epoch 44/50
# 4/4 [==============================] - 1s 294ms/step - loss: 0.2375 - accuracy: 0.9272
# Epoch 45/50
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2373 - accuracy: 0.9272
# Epoch 46/50
# 4/4 [==============================] - 1s 295ms/step - loss: 0.2373 - accuracy: 0.9272
# Epoch 47/50
# 4/4 [==============================] - 1s 295ms/step - loss: 0.2371 - accuracy: 0.9272
# Epoch 48/50
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2369 - accuracy: 0.9273
# Epoch 49/50
# 4/4 [==============================] - 1s 316ms/step - loss: 0.2367 - accuracy: 0.9273
# Epoch 50/50
# 4/4 [==============================] - 1s 284ms/step - loss: 0.2369 - accuracy: 0.9272

# %%
BATCH_SIZE = 16 * tpu_strategy.num_replicas_in_sync
BATCH_SIZE
# Out:
# 128

# %%
with tpu_strategy.scope():
    modelB = Sequential()
    modelB.add(Dense(64, input_shape=(54,), activation='relu'))
    modelB.add(Dense(1, activation='sigmoid'))
    modelB.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    modelB.fit(trainXB,trainYB,epochs=50, steps_per_epoch=4)
# Out:
# 2022-10-10 06:36:48.384609: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2019940848 exceeds 10% of free system memory.
# Epoch 1/50
# 4/4 [==============================] - 5s 128ms/step - loss: 0.9026 - accuracy: 0.3201
# Epoch 2/50
# 4/4 [==============================] - 1s 333ms/step - loss: 0.7939 - accuracy: 0.4265
# Epoch 3/50
# 4/4 [==============================] - 1s 323ms/step - loss: 0.6978 - accuracy: 0.5496
# Epoch 4/50
# 4/4 [==============================] - 1s 306ms/step - loss: 0.6146 - accuracy: 0.6716
# Epoch 5/50
# 4/4 [==============================] - 1s 315ms/step - loss: 0.5437 - accuracy: 0.7745
# Epoch 6/50
# 4/4 [==============================] - 1s 340ms/step - loss: 0.4847 - accuracy: 0.8470
# Epoch 7/50
# 4/4 [==============================] - 1s 347ms/step - loss: 0.4361 - accuracy: 0.8904
# Epoch 8/50
# 4/4 [==============================] - 1s 301ms/step - loss: 0.3967 - accuracy: 0.9125
# Epoch 9/50
# 4/4 [==============================] - 1s 315ms/step - loss: 0.3651 - accuracy: 0.9226
# Epoch 10/50
# 4/4 [==============================] - 1s 301ms/step - loss: 0.3401 - accuracy: 0.9268
# Epoch 11/50
# 4/4 [==============================] - 1s 310ms/step - loss: 0.3201 - accuracy: 0.9286
# Epoch 12/50
# 4/4 [==============================] - 1s 310ms/step - loss: 0.3046 - accuracy: 0.9292
# Epoch 13/50
# 4/4 [==============================] - 1s 305ms/step - loss: 0.2925 - accuracy: 0.9294
# Epoch 14/50
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2826 - accuracy: 0.9296
# Epoch 15/50
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2754 - accuracy: 0.9295
# Epoch 16/50
# 4/4 [==============================] - 1s 301ms/step - loss: 0.2691 - accuracy: 0.9297
# Epoch 17/50
# 4/4 [==============================] - 1s 299ms/step - loss: 0.2642 - accuracy: 0.9297
# Epoch 18/50
# 4/4 [==============================] - 1s 317ms/step - loss: 0.2605 - accuracy: 0.9297
# Epoch 19/50
# 4/4 [==============================] - 1s 298ms/step - loss: 0.2576 - accuracy: 0.9296
# Epoch 20/50
# 4/4 [==============================] - 1s 312ms/step - loss: 0.2552 - accuracy: 0.9296
# Epoch 21/50
# 4/4 [==============================] - 1s 314ms/step - loss: 0.2532 - accuracy: 0.9296
# Epoch 22/50
# 4/4 [==============================] - 1s 306ms/step - loss: 0.2515 - accuracy: 0.9296
# Epoch 23/50
# 4/4 [==============================] - 1s 314ms/step - loss: 0.2499 - accuracy: 0.9296
# Epoch 24/50
# 4/4 [==============================] - 1s 310ms/step - loss: 0.2486 - accuracy: 0.9297
# Epoch 25/50
# 4/4 [==============================] - 1s 298ms/step - loss: 0.2477 - accuracy: 0.9297
# Epoch 26/50
# 4/4 [==============================] - 1s 308ms/step - loss: 0.2470 - accuracy: 0.9296
# Epoch 27/50
# 4/4 [==============================] - 1s 284ms/step - loss: 0.2461 - accuracy: 0.9296
# Epoch 28/50
# 4/4 [==============================] - 1s 297ms/step - loss: 0.2454 - accuracy: 0.9296
# Epoch 29/50
# 4/4 [==============================] - 1s 292ms/step - loss: 0.2447 - accuracy: 0.9297
# Epoch 30/50
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2444 - accuracy: 0.9296
# Epoch 31/50
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2438 - accuracy: 0.9296
# Epoch 32/50
# 4/4 [==============================] - 1s 296ms/step - loss: 0.2433 - accuracy: 0.9297
# Epoch 33/50
# 4/4 [==============================] - 1s 295ms/step - loss: 0.2429 - accuracy: 0.9297
# Epoch 34/50
# 4/4 [==============================] - 1s 296ms/step - loss: 0.2427 - accuracy: 0.9296
# Epoch 35/50
# 4/4 [==============================] - 1s 302ms/step - loss: 0.2424 - accuracy: 0.9296
# Epoch 36/50
# 4/4 [==============================] - 1s 288ms/step - loss: 0.2422 - accuracy: 0.9296
# Epoch 37/50
# 4/4 [==============================] - 1s 289ms/step - loss: 0.2418 - accuracy: 0.9296
# Epoch 38/50
# 4/4 [==============================] - 1s 286ms/step - loss: 0.2416 - accuracy: 0.9296
# Epoch 39/50
# 4/4 [==============================] - 1s 283ms/step - loss: 0.2412 - accuracy: 0.9297
# Epoch 40/50
# 4/4 [==============================] - 1s 278ms/step - loss: 0.2411 - accuracy: 0.9296
# Epoch 41/50
# 4/4 [==============================] - 1s 287ms/step - loss: 0.2408 - accuracy: 0.9297
# Epoch 42/50
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2406 - accuracy: 0.9297
# Epoch 43/50
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2404 - accuracy: 0.9297
# Epoch 44/50
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2402 - accuracy: 0.9297
# Epoch 45/50
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2399 - accuracy: 0.9297
# Epoch 46/50
# 4/4 [==============================] - 1s 297ms/step - loss: 0.2398 - accuracy: 0.9297
# Epoch 47/50
# 4/4 [==============================] - 1s 288ms/step - loss: 0.2398 - accuracy: 0.9296
# Epoch 48/50
# 4/4 [==============================] - 1s 299ms/step - loss: 0.2397 - accuracy: 0.9296
# Epoch 49/50
# 4/4 [==============================] - 1s 293ms/step - loss: 0.2395 - accuracy: 0.9297
# Epoch 50/50
# 4/4 [==============================] - 1s 302ms/step - loss: 0.2392 - accuracy: 0.9297

# %%
with tpu_strategy.scope():
    A = modelA.predict(test)
    B = modelB.predict(test)

# %%
A = [int(a>0.5) for a in A]
B = [int(a>0.5) for a in B]

# %%
ss = pd.read_csv('../input/tabular-playground-series-oct-2022/sample_submission.csv')

# %%
df = pd.DataFrame({'id':ss.id,'team_A_scoring_within_10sec':A,'team_B_scoring_within_10sec':B})

# %%
df.to_csv('SS6.csv',index = False)
